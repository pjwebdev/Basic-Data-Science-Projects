# %% [markdown]
# # Loading libraries & Setup

# %% [markdown]
# Importing Tweepy, TextBlob, WordCloud, Pandas, Numpy and Matplotlib.

# %%
# Tweepy - Python library for accessing the Twitter API.
import tweepy

# TextBlob - Python library for processing textual data
from textblob import TextBlob

# WordCloud - Python linrary for creating image wordclouds
from wordcloud import WordCloud

# Pandas - Data manipulation and analysis library
import pandas as pd

# NumPy - mathematical functions on multi-dimensional arrays and matrices
import numpy as np

# Regular Expression Python module
import re

# Matplotlib - plotting library to create graphs and charts
import matplotlib.pyplot as plt

# Settings for Matplotlib graphs and charts
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

# conda install tweepy
# conda install textblob
# conda install wordcloud

# %% [markdown]
# Let's load the config file (make sure you edit the config file and enter you Twitter API details as described in the inttroductioon).

# %%
config = pd.read_csv("./config.csv")

# %% [markdown]
# Now we need to set all Twitter API config variables required for autherntication with Tweepy.

# %%
# Twitter API config
twitterApiKey = config['twitterApiKey'][0]
twitterApiSecret = config['twitterApiSecret'][0]
twitterApiAccessToken = config['twitterApiAccessToken'][0]
twitterApiAccessTokenSecret = config['twitterApiAccessTokenSecret'][0]

# %% [markdown]
# We are making an authentication call with Tweepy so we can call a function to retrieve the latest tweets from the specified account.

# %%
# Authenticate
auth = tweepy.OAuthHandler(twitterApiKey, twitterApiSecret)
auth.set_access_token(twitterApiAccessToken, twitterApiAccessTokenSecret)
twetterApi = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# Feel free to change the Tweeter account to a different one.

# %%
twitterAccount = "elonmusk"

# %% [markdown]
# Now we are going to retrieve the last 50 Tweets & replies from the specified Tweeter account.

# %%
tweets = tweepy.Cursor(twetterApi.user_timeline, 
                        screen_name=twitterAccount, 
                        count=None,
                        since_id=None,
                        max_id=None,
                        trim_user=True,
                        exclude_replies=True,
                        contributor_details=False,
                        include_entities=False
                        ).items(50);

# %% [markdown]
# And we are going to create Pandas Data Frame from it.

# %%
df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweet'])

# %% [markdown]
# Let's see what is in the data frame by calling the head() function.

# %%
df.head()
# Out:
#                                                Tweet
# 0                                      Pronouns suck
# 1                                    🌹 Twitter sucks
# 2  Another government stimulus package is not in ...
# 3  Tesla solar panels are $1.49/Watt \nhttps://t....
# 4  RT @Commercial_Crew: While in orbit, astronaut...

# %% [markdown]
# Before we start our sentiment analysis it is a good idea to clean up each tweets from an unnecessary data first.
#
# We are going to create a cleanUpTweet function that will:
# - remove mentions
# - remove hashtags
# - remove retweets
# - remove urls

# %%
# Cleaning the tweets

def cleanUpTweet(txt):
    # Remove mentions
    txt = re.sub(r'@[A-Za-z0-9_]+', '', txt)
    # Remove hashtags
    txt = re.sub(r'#', '', txt)
    # Remove retweets:
    txt = re.sub(r'RT : ', '', txt)
    # Remove urls
    txt = re.sub(r'https?:\/\/[A-Za-z0-9\.\/]+', '', txt)
    return txt

# %% [markdown]
# And nw we are going to apply it for all the Tweets in our Pandas Data Frame.

# %%
df['Tweet'] = df['Tweet'].apply(cleanUpTweet)

# %% [markdown]
# We are also going to build a couple more functions to calculate the subjectivity and polarity of our tweets.

# %%
def getTextSubjectivity(txt):
    return TextBlob(txt).sentiment.subjectivity

def getTextPolarity(txt):
    return TextBlob(txt).sentiment.polarity

# %% [markdown]
# And now we are going to apply these functions to our data frame and create two new features in our data frame Subjectivity and Polarity.

# %%
df['Subjectivity'] = df['Tweet'].apply(getTextSubjectivity)
df['Polarity'] = df['Tweet'].apply(getTextPolarity)

# %% [markdown]
# Now, let's see how our data frame looks now.

# %%
df.head(50)
# Out:
#                                                 Tweet  Subjectivity  Polarity
# 0                                       Pronouns suck      0.000000  0.000000
# 1                                     🌹 Twitter sucks      0.300000 -0.300000
# 2   Another government stimulus package is not in ...      0.300000  1.000000
# 3                Tesla solar panels are $1.49/Watt \n      0.000000  0.000000
# 4   While in orbit, astronauts  and  performed a h...      0.000000  0.000000
# 5   Impressive Tianwen-1 Mars rover mission launch...      1.000000  1.000000
# 6                                                          0.000000  0.000000
# 7               You don’t have a soul, you are a soul      0.000000  0.000000
# 8                                  2 minutes later …       0.000000  0.000000
# 9                                        Coming soon       0.000000  0.000000
# 10         Where are the memes? Send in … the memes …      0.000000  0.000000
# 11  Nothing has gaslit more people than the movie ...      0.500000  0.500000
# 12  Videos of yesterday’s catch of both fairing ha...      0.000000  0.000000
# 13               Watch Falcon 9 launch ANASIS-II →         0.000000  0.000000
# 14         Das baby kann noch keinen löffel benutzen       0.000000  0.000000
# 15   Both fairing halves caught from space by  ships!      0.000000  0.000000
# 16  Falcon 9’s first stage has landed on the Just ...      0.333333  0.250000
# 17                                 Launch in 20 mins       0.000000  0.000000
# 18  Tesla's Model 3 received top marks from safety...      0.500000  0.500000
# 19                                                         0.000000  0.000000
# 20  Targeting Monday, July 20 for Falcon 9 launch ...      0.000000  0.000000
# 21  If you’ve solved hard problems with phones / w...      0.541667 -0.291667
# 22                                   It’s inevitable       1.000000  0.000000
# 23  Will those who write the algorithms ever reali...      0.000000  0.000000
# 24                                       Giga Berlin       0.000000  0.000000
# 25                                                         0.000000  0.000000
# 26  I spoke with Korolev’s family today.\nHe was o...      0.390000  1.000000
# 27                 Best use of the term “Full Stack”?      0.425000  0.675000
# 28  If you can’t beat em, join em\nNeuralink missi...      0.000000  0.000000
# 29  Falcon 9 lands on Just Read the Instructions a...      0.000000  0.000000
# 30  Read The Story of Civilization by Will &amp; A...      0.000000  0.000000
# 31     Limited edition short shorts now available at       0.280952  0.109524
# 32   "Orbiting Earth in the spaceship, I saw how b...      1.000000  0.850000
# 33                  Beautiful fireworks in LA tonight      1.000000  0.850000
# 34  North American Supercharger usage is now at pr...      0.413333 -0.080000
# 35                                                         0.000000  0.000000
# 36  Please take a moment to report accounts clearl...      0.483333  0.033333
# 37                      🇺🇸🇺🇸 Happy 4th of July!! 🇺🇸🇺🇸      1.000000  1.000000
# 38                     Congrats Tesla Team — U ROK!!       0.000000  0.000000
# 39                        Crew Dragon docked to the        0.000000  0.000000
# 40  Tesla Q2 2020 Vehicle Production &amp; Deliver...      0.000000  0.000000
# 41  Thanks Tesla owners &amp; investors! Love you!...      0.502083  0.268229
# 42  Just over a month ago,  &amp;  launched to the...      0.000000  0.000000
# 43   SEC, three letter acronym, middle word is Elon’s      0.300000 -0.050000
# 44  Tesla will make fabulous short shorts in radia...      0.433333  0.133333
# 45                         Who wears short shorts? 🤣🤣      0.300000  0.000000
# 46  Tesla crushes Wall Street’s Q2 estimates with ...      0.000000  0.000000
# 47  Tesla Impact Report (repost). We do everything...      1.000000  0.000000
# 48                 Your GPS just got slightly better       0.500000  0.500000
# 49  Falcon 9’s first stage has landed on the Just ...      0.333333  0.312500

# %% [markdown]
# We have some empty rows here so before further processing let's remove those.

# %% [markdown]
# The below command will remove all the rows with the Tweet column equals to "".

# %%
df = df.drop(df[df['Tweet'] == ''].index)

# %%
df.head(50)
# Out:
#                                                 Tweet  Subjectivity  Polarity
# 0                                       Pronouns suck      0.000000  0.000000
# 1                                     🌹 Twitter sucks      0.300000 -0.300000
# 2   Another government stimulus package is not in ...      0.300000  1.000000
# 3                Tesla solar panels are $1.49/Watt \n      0.000000  0.000000
# 4   While in orbit, astronauts  and  performed a h...      0.000000  0.000000
# 5   Impressive Tianwen-1 Mars rover mission launch...      1.000000  1.000000
# 7               You don’t have a soul, you are a soul      0.000000  0.000000
# 8                                  2 minutes later …       0.000000  0.000000
# 9                                        Coming soon       0.000000  0.000000
# 10         Where are the memes? Send in … the memes …      0.000000  0.000000
# 11  Nothing has gaslit more people than the movie ...      0.500000  0.500000
# 12  Videos of yesterday’s catch of both fairing ha...      0.000000  0.000000
# 13               Watch Falcon 9 launch ANASIS-II →         0.000000  0.000000
# 14         Das baby kann noch keinen löffel benutzen       0.000000  0.000000
# 15   Both fairing halves caught from space by  ships!      0.000000  0.000000
# 16  Falcon 9’s first stage has landed on the Just ...      0.333333  0.250000
# 17                                 Launch in 20 mins       0.000000  0.000000
# 18  Tesla's Model 3 received top marks from safety...      0.500000  0.500000
# 20  Targeting Monday, July 20 for Falcon 9 launch ...      0.000000  0.000000
# 21  If you’ve solved hard problems with phones / w...      0.541667 -0.291667
# 22                                   It’s inevitable       1.000000  0.000000
# 23  Will those who write the algorithms ever reali...      0.000000  0.000000
# 24                                       Giga Berlin       0.000000  0.000000
# 26  I spoke with Korolev’s family today.\nHe was o...      0.390000  1.000000
# 27                 Best use of the term “Full Stack”?      0.425000  0.675000
# 28  If you can’t beat em, join em\nNeuralink missi...      0.000000  0.000000
# 29  Falcon 9 lands on Just Read the Instructions a...      0.000000  0.000000
# 30  Read The Story of Civilization by Will &amp; A...      0.000000  0.000000
# 31     Limited edition short shorts now available at       0.280952  0.109524
# 32   "Orbiting Earth in the spaceship, I saw how b...      1.000000  0.850000
# 33                  Beautiful fireworks in LA tonight      1.000000  0.850000
# 34  North American Supercharger usage is now at pr...      0.413333 -0.080000
# 36  Please take a moment to report accounts clearl...      0.483333  0.033333
# 37                      🇺🇸🇺🇸 Happy 4th of July!! 🇺🇸🇺🇸      1.000000  1.000000
# 38                     Congrats Tesla Team — U ROK!!       0.000000  0.000000
# 39                        Crew Dragon docked to the        0.000000  0.000000
# 40  Tesla Q2 2020 Vehicle Production &amp; Deliver...      0.000000  0.000000
# 41  Thanks Tesla owners &amp; investors! Love you!...      0.502083  0.268229
# 42  Just over a month ago,  &amp;  launched to the...      0.000000  0.000000
# 43   SEC, three letter acronym, middle word is Elon’s      0.300000 -0.050000
# 44  Tesla will make fabulous short shorts in radia...      0.433333  0.133333
# 45                         Who wears short shorts? 🤣🤣      0.300000  0.000000
# 46  Tesla crushes Wall Street’s Q2 estimates with ...      0.000000  0.000000
# 47  Tesla Impact Report (repost). We do everything...      1.000000  0.000000
# 48                 Your GPS just got slightly better       0.500000  0.500000
# 49  Falcon 9’s first stage has landed on the Just ...      0.333333  0.312500

# %% [markdown]
# We can see that we have a calculated score for the subjectivity and polarity in our data frame.

# %% [markdown]
# Now let's build a function and categorize our tweets as Negative, Neutral and Positive.

# %%
# negative, nautral, positive analysis
def getTextAnalysis(a):
    if a < 0:
        return "Negative"
    elif a == 0:
        return "Neutral"
    else:
        return "Positive"

# %% [markdown]
# And apply this functiona and create another feature in our data frame called Score.

# %%
df['Score'] = df['Polarity'].apply(getTextAnalysis)

# %% [markdown]
# Here is our data frame with our Tweets, Subjectivity, Polarity and Score for all our Tweets.

# %%
df.head(50)
# Out:
#                                                 Tweet  Subjectivity  Polarity  \
# 0                                       Pronouns suck      0.000000  0.000000
# 1                                     🌹 Twitter sucks      0.300000 -0.300000
# 2   Another government stimulus package is not in ...      0.300000  1.000000
# 3                Tesla solar panels are $1.49/Watt \n      0.000000  0.000000
# 4   While in orbit, astronauts  and  performed a h...      0.000000  0.000000
# 5   Impressive Tianwen-1 Mars rover mission launch...      1.000000  1.000000
# 7               You don’t have a soul, you are a soul      0.000000  0.000000
# 8                                  2 minutes later …       0.000000  0.000000
# 9                                        Coming soon       0.000000  0.000000
# 10         Where are the memes? Send in … the memes …      0.000000  0.000000
# 11  Nothing has gaslit more people than the movie ...      0.500000  0.500000
# 12  Videos of yesterday’s catch of both fairing ha...      0.000000  0.000000
# 13               Watch Falcon 9 launch ANASIS-II →         0.000000  0.000000
# 14         Das baby kann noch keinen löffel benutzen       0.000000  0.000000
# 15   Both fairing halves caught from space by  ships!      0.000000  0.000000
# 16  Falcon 9’s first stage has landed on the Just ...      0.333333  0.250000
# 17                                 Launch in 20 mins       0.000000  0.000000
# 18  Tesla's Model 3 received top marks from safety...      0.500000  0.500000
# 20  Targeting Monday, July 20 for Falcon 9 launch ...      0.000000  0.000000
# 21  If you’ve solved hard problems with phones / w...      0.541667 -0.291667
# 22                                   It’s inevitable       1.000000  0.000000
# 23  Will those who write the algorithms ever reali...      0.000000  0.000000
# 24                                       Giga Berlin       0.000000  0.000000
# 26  I spoke with Korolev’s family today.\nHe was o...      0.390000  1.000000
# 27                 Best use of the term “Full Stack”?      0.425000  0.675000
# 28  If you can’t beat em, join em\nNeuralink missi...      0.000000  0.000000
# 29  Falcon 9 lands on Just Read the Instructions a...      0.000000  0.000000
# 30  Read The Story of Civilization by Will &amp; A...      0.000000  0.000000
# 31     Limited edition short shorts now available at       0.280952  0.109524
# 32   "Orbiting Earth in the spaceship, I saw how b...      1.000000  0.850000
# 33                  Beautiful fireworks in LA tonight      1.000000  0.850000
# 34  North American Supercharger usage is now at pr...      0.413333 -0.080000
# 36  Please take a moment to report accounts clearl...      0.483333  0.033333
# 37                      🇺🇸🇺🇸 Happy 4th of July!! 🇺🇸🇺🇸      1.000000  1.000000
# 38                     Congrats Tesla Team — U ROK!!       0.000000  0.000000
# 39                        Crew Dragon docked to the        0.000000  0.000000
# 40  Tesla Q2 2020 Vehicle Production &amp; Deliver...      0.000000  0.000000
# 41  Thanks Tesla owners &amp; investors! Love you!...      0.502083  0.268229
# 42  Just over a month ago,  &amp;  launched to the...      0.000000  0.000000
# 43   SEC, three letter acronym, middle word is Elon’s      0.300000 -0.050000
# 44  Tesla will make fabulous short shorts in radia...      0.433333  0.133333
# 45                         Who wears short shorts? 🤣🤣      0.300000  0.000000
# 46  Tesla crushes Wall Street’s Q2 estimates with ...      0.000000  0.000000
# 47  Tesla Impact Report (repost). We do everything...      1.000000  0.000000
# 48                 Your GPS just got slightly better       0.500000  0.500000
# 49  Falcon 9’s first stage has landed on the Just ...      0.333333  0.312500
#
#        Score
# 0    Neutral
# 1   Negative
# 2   Positive
# 3    Neutral
# 4    Neutral
# 5   Positive
# 7    Neutral
# 8    Neutral
# 9    Neutral
# 10   Neutral
# 11  Positive
# 12   Neutral
# 13   Neutral
# 14   Neutral
# 15   Neutral
# 16  Positive
# 17   Neutral
# 18  Positive
# 20   Neutral
# 21  Negative
# 22   Neutral
# 23   Neutral
# 24   Neutral
# 26  Positive
# 27  Positive
# 28   Neutral
# 29   Neutral
# 30   Neutral
# 31  Positive
# 32  Positive
# 33  Positive
# 34  Negative
# 36  Positive
# 37  Positive
# 38   Neutral
# 39   Neutral
# 40   Neutral
# 41  Positive
# 42   Neutral
# 43  Negative
# 44  Positive
# 45   Neutral
# 46   Neutral
# 47   Neutral
# 48  Positive
# 49  Positive

# %% [markdown]
# Let;s now take all positive tweets and calculate the percentage of positive tweets from all the tweets in our data frame.

# %%
positive = df[df['Score'] == 'Positive']

print(str(positive.shape[0]/(df.shape[0])*100) + " % of positive tweets")
# Out:
# 34.78260869565217 % of positive tweets

# %% [markdown]
# We can now visualise positive, negative, neutral tweets using Matplotlib.

# %%
labels = df.groupby('Score').count().index.values

values = df.groupby('Score').size().values

plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# We can see how Negative, Neutral and Positive tweets spread on this account.

# %% [markdown]
# We can also visualise the same information by displaying the exact values of subjectivity and polatiry on the graph.

# %%
for index, row in df.iterrows():
    if row['Score'] == 'Positive':
        plt.scatter(row['Polarity'], row['Subjectivity'], color="green")
    elif row['Score'] == 'Negative':
        plt.scatter(row['Polarity'], row['Subjectivity'], color="red")
    elif row['Score'] == 'Neutral':
        plt.scatter(row['Polarity'], row['Subjectivity'], color="blue")

plt.title('Twitter Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
# add legend
plt.show()

# %% [markdown]
# We can also calculate the percentage of objective tweets.

# %%
objective = df[df['Subjectivity'] == 0]

print(str(objective.shape[0]/(df.shape[0])*100) + " % of objective tweets")
# Out:
# 50.0 % of objective tweets

# %% [markdown]
# At the end we can also generate a wrod cloud to see the themes and most common words used in the tweets we were analysing.

# %%
# Creating a word cloud
words = ' '.join([tweet for tweet in df['Tweet']])
wordCloud = WordCloud(width=600, height=400).generate(words)

plt.imshow(wordCloud)
plt.show()

# %% [markdown]
# Doing sentiment analysis of the tweets enabled us to calculate numerical values of subjectivity and polarity.
#
# This could help us to understand better this Tweeter account in terms of the language that is being used.
#
# Combining this with additional information about likes and comments can be very useful from marketing point of view and can enable us to find some correlation betweein subjectivity, polarity and the engagement our the users for a specified Tweeeter account.
#
# We encourage you to experiment more with this example and come up with some more ideas how this can be used in practice.
